# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot  as plt
from scipy import stats as ss

# %%
links= pd.read_csv(r"C:\Users\gowrabathina RAKESH\Downloads\movie_data\links.csv")

# %%
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
movies= pd.read_csv(r"C:\Users\gowrabathina RAKESH\Downloads\movie_data\movies.csv")

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
ratings=pd.read_csv(r"C:\Users\gowrabathina RAKESH\Downloads\movie_data\ratings.csv")

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
tags=pd.read_csv(r"C:\Users\gowrabathina RAKESH\Downloads\movie_data\tags.csv")

# %%
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
#How many unique "userId" are available in "ratings.csv"?
ratings["userId"].nunique()
# Out:
# 610

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
movies.groupby("movieId").size().reset_index(name="rating")
# Out:
#       movieId  rating
# 0           1       1
# 1           2       1
# 2           3       1
# 3           4       1
# 4           5       1
# ...       ...     ...
# 9737   193581       1
# 9738   193583       1
# 9739   193585       1
# 9740   193587       1
# 9741   193609       1
#
# [9742 rows x 2 columns]

# %%
movie = ratings.groupby('movieId').size().reset_index(name='ratings_count')

# %%
movie
# Out:
#       movieId  ratings_count
# 0           1            215
# 1           2            110
# 2           3             52
# 3           4              7
# 4           5             49
# ...       ...            ...
# 9719   193581              1
# 9720   193583              1
# 9721   193585              1
# 9722   193587              1
# 9723   193609              1
#
# [9724 rows x 2 columns]

# %%
movie = movie.loc[movie['ratings_count'].idxmax()]

# %%
movie
# Out:
# movieId          356
# ratings_count    329
# Name: 314, dtype: int64

# %%
movie_id_max_max = max_ratings_movie['movieId']
count = max_ratings_movie['ratings_count']

# %%
movie_id
# Out:
# 356

# %%
count
# Out:
# 329

# %%
max_ratings_movie_title = movies.loc[movies['movieId'] == movie_id, 'title'].values[0]

# %%
max_ratings_movie_title
# Out:
# 'Forrest Gump (1994)'

# %%
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
movies["genres"].nunique()
# Out:
# 951

# %%
tags.groupby("movieId").size().reset_index(name="rating")
# Out:
#       movieId  rating
# 0           1       3
# 1           2       4
# 2           3       2
# 3           5       2
# 4           7       1
# ...       ...     ...
# 1567   183611       3
# 1568   184471       3
# 1569   187593       3
# 1570   187595       2
# 1571   193565       4
#
# [1572 rows x 2 columns]

# %%
movie = ratings.groupby('movieId').size().reset_index(name='userid')

# %%
movie
# Out:
# movieId    356
# userid     329
# Name: 314, dtype: int64

# %%
tag = ratings.groupby('movieId').size().reset_index(name='ratings_count')

# %%
tag
# Out:
#       movieId  ratings_count
# 0           1            215
# 1           2            110
# 2           3             52
# 3           4              7
# 4           5             49
# ...       ...            ...
# 9719   193581              1
# 9720   193583              1
# 9721   193585              1
# 9722   193587              1
# 9723   193609              1
#
# [9724 rows x 2 columns]

# %%
tag = tags.loc[tag['ratings_count'].idxmax()]

# %%
tag
# Out:
# userId                      62
# movieId                 122912
# tag          Robert Downey Jr.
# timestamp           1526028991
# Name: 314, dtype: object

# %%
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
s = tags[tags["movieId"]=="Matrix, The (1999)"]["tag"]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 titles
#
# NameError: name 'titles' is not defined

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
movies["title"]=="Matrix, The (1999)"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9737    False
# 9738    False
# 9739    False
# 9740    False
# 9741    False
# Name: title, Length: 9742, dtype: bool

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
fight_club_ratings = ratings[ratings['title'] == 'Fight Club (1999)']['rating']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plt.figure(figsize=(8, 6))
plt.hist(fight_club_ratings, bins=5, color='skyblue', edgecolor='black')
plt.title('User Ratings Distribution for Fight Club (1999)')
plt.xlabel('Rating')
plt.ylabel('Number of Users')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[177], line 2
#       1 plt.figure(figsize=(8, 6))
# ----> 2 plt.hist(fight_club_ratings, bins=5, color='skyblue', edgecolor='black')
#       3 plt.title('User Ratings Distribution for Fight Club (1999)')
#       4 plt.xlabel('Rating')
#
# NameError: name 'fight_club_ratings' is not defined

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
df_merge.groupby('movieId')['rating'].agg('max').sort_values(ascending=False).value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[183], line 1
# ----> 1 df_merge.groupby('movieId')['rating'].agg('max').sort_values(ascending=False).value_counts()
#
# NameError: name 'df_merge' is not defined

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
df_merge = pd.merge(movies,ratings, on='movieId',how='inner')

# %%
df_merge
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
df_merge_t = pd.merge(df_merge,tags,on='movieId',how='inner')

# %%
df_merge_t
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy         5     4.0
# ...

# %%
df_merge_l = pd.merge(df_merge_t,links,on='movieId', how='inner')

# %%
df_merge_l
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy         5     4.0
# ...

# %%
df = pd.DataFrame(df_merge)

# %%
df
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
df.groupby('rating')

# %%
df_merge
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
s = ratings.groupby('rating')

# %%
s.mean()
# Out:
#             userId       movieId     timestamp
# rating
# 0.5     334.536496  28267.988321  1.326879e+09
# 1.0     329.784063  14819.926361  1.135150e+09
# 1.5     376.597990  30537.082077  1.326353e+09
# 2.0     325.257714  15496.788108  1.155335e+09
# 2.5     363.685946  25686.934595  1.319181e+09
# 3.0     326.648775  14853.203173  1.141352e+09
# 3.5     337.152406  26388.434074  1.297586e+09
# 4.0     320.366321  17858.161496  1.181583e+09
# 4.5     315.131096  27504.881067  1.308974e+09
# 5.0     309.413670  15638.924154  1.163170e+09

# %%
s.count()
# Out:
#         userId  movieId  timestamp
# rating
# 0.5       1370     1370       1370
# 1.0       2811     2811       2811
# 1.5       1791     1791       1791
# 2.0       7551     7551       7551
# 2.5       5550     5550       5550
# 3.0      20047    20047      20047
# 3.5      13136    13136      13136
# 4.0      26818    26818      26818
# 4.5       8551     8551       8551
# 5.0      13211    13211      13211

# %%
s.max()
# Out:
#         userId  movieId   timestamp
# rating
# 0.5        610   184641  1537158378
# 1.0        610   190221  1537158428
# 1.5        610   190215  1537757059
# 2.0        610   185033  1537158460
# 2.5        610   189713  1537757040
# 3.0        610   193567  1537674946
# 3.5        610   193587  1537470521
# 4.0        610   193609  1537799250
# 4.5        610   191005  1537632293
# 5.0        610   187717  1537632257

# %%
mov_rat = df_merge[df_merge['title']=='Terminator 2: Judgment Day (1991)']

# %%
mov_rat
# Out:
#        movieId                              title         genres  userId  \
# 15651      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       5
# 15652      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       6
# 15653      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       7
# 15654      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      11
# 15655      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      15
# ...        ...                                ...            ...     ...
# 15870      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     606
# 15871      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     607
# 15872      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     608
# 15873      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     609
# 15874      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     610
#
#        rating   timestamp
# 15651     3.0   847435258
# 15652     3.0   845553317
# ...

# %%
mov_rat.groupby('rating')

# %%
df1 = pd.DataFrame(mov_rat)

# %%
mov_rat['rating'].mean()
# Out:
# 3.970982142857143

# %%
df_fg = df_merge[df_merge['title']=='Fight Club (1999)']

# %%
df_fg
# Out:
#        movieId              title                       genres  userId  \
# 49835     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       1
# 49836     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       4
# 49837     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      10
# 49838     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      15
# 49839     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      16
# ...        ...                ...                          ...     ...
# 50048     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     601
# 50049     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     603
# 50050     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     606
# 50051     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     608
# 50052     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     610
#
#        rating   timestamp
# 49835     5.0   964983282
# 49836     2.0   945078528
# 49837     0.5  1455356582
# ...

# %%
df_fg["rating"].unique()
# Out:
# array([5. , 2. , 0.5, 2.5, 3.5, 4.5, 4. , 3. , 1.5])

# %%
mov_rat.groupby('rating')

# %%
df1 = pd.DataFrame(mov_rat)

# %%
df1
# Out:
#        movieId                              title         genres  userId  \
# 15651      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       5
# 15652      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       6
# 15653      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       7
# 15654      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      11
# 15655      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      15
# ...        ...                                ...            ...     ...
# 15870      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     606
# 15871      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     607
# 15872      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     608
# 15873      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     609
# 15874      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     610
#
#        rating   timestamp
# 15651     3.0   847435258
# 15652     3.0   845553317
# ...

# %%
df1.groupby('rating')

# %%
mov_rat['rating'].mean()
# Out:
# 3.970982142857143

# %%
df_fg = df_merge[df_merge['title']=='Fight Club (1999)']

# %%
df_fg
# Out:
#        movieId              title                       genres  userId  \
# 49835     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       1
# 49836     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       4
# 49837     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      10
# 49838     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      15
# 49839     2959  Fight Club (1999)  Action|Crime|Drama|Thriller      16
# ...        ...                ...                          ...     ...
# 50048     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     601
# 50049     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     603
# 50050     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     606
# 50051     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     608
# 50052     2959  Fight Club (1999)  Action|Crime|Drama|Thriller     610
#
#        rating   timestamp
# 49835     5.0   964983282
# 49836     2.0   945078528
# 49837     0.5  1455356582
# ...

# %%
df_rat = df_fg['rating']

# %%
df_rat
# Out:
# 49835    5.0
# 49836    2.0
# 49837    0.5
# 49838    2.5
# 49839    3.5
#         ...
# 50048    5.0
# 50049    4.0
# 50050    5.0
# 50051    5.0
# 50052    5.0
# Name: rating, Length: 218, dtype: float64

# %%
df_rat
# Out:
# 49835    5.0
# 49836    2.0
# 49837    0.5
# 49838    2.5
# 49839    3.5
#         ...
# 50048    5.0
# 50049    4.0
# 50050    5.0
# 50051    5.0
# 50052    5.0
# Name: rating, Length: 218, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
import numpy as np

# %%
plt.kdeplot(df_rat, kde=True)
plt.title('Histogram and Normal Distribution Fit')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[248], line 1
# ----> 1 plt.kdeplot(df_rat, kde=True)
#       2 plt.title('Histogram and Normal Distribution Fit')
#       3 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'kdeplot'

# %% [markdown]
# !![image.png](attachment:image.png)

# %%
movies.groupby("movieId").size().reset_index(name="rating")
# Out:
#       movieId  rating
# 0           1       1
# 1           2       1
# 2           3       1
# 3           4       1
# 4           5       1
# ...       ...     ...
# 9737   193581       1
# 9738   193583       1
# 9739   193585       1
# 9740   193587       1
# 9741   193609       1
#
# [9742 rows x 2 columns]

# %%
cr_tag = df_merge_t[df_merge_t['title']=='Matrix, The (1999)']

# %%
cr_tag['tag'].value_counts()
# Out:
# martial arts          278
# sci-fi                278
# alternate universe    278
# philosophy            278
# post apocalyptic      278
# Name: tag, dtype: int64

# %%
rat = ratings.groupby('movieId')['rating'].agg(['count','mean'])

# %%
rat
# Out:
#          count      mean
# movieId
# 1          215  3.920930
# 2          110  3.431818
# 3           52  3.259615
# 4            7  2.357143
# 5           49  3.071429
# ...        ...       ...
# 193581       1  4.000000
# 193583       1  3.500000
# 193585       1  3.500000
# 193587       1  3.500000
# 193609       1  4.000000
#
# [9724 rows x 2 columns]

# %%
df_gr = pd.merge(rat,movie, on='movieId')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[226], line 1
# ----> 1 df_gr = pd.merge(rat,movie, on='movieId')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
# ...

# %%
df_gr.groupby('title')['count'].agg('max').sort_values(ascending=False).head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[227], line 1
# ----> 1 df_gr.groupby('title')['count'].agg('max').sort_values(ascending=False).head(5)
#
# NameError: name 'df_gr' is not defined

# %%
df_merge.groupby('movieId')['rating'].agg('max').sort_values(ascending=False).value_counts()
# Out:
# 5.0    2954
# 4.0    2242
# 4.5    1102
# 3.0    1089
# 3.5    1065
# 2.0     444
# 2.5     400
# 1.5     181
# 1.0     151
# 0.5      96
# Name: rating, dtype: int64

# %%
import requests
import numpy as np
from bs4 import FILL_IN_THE_BLANK

def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    request_header = {'Content-Type': 'text/html; charset=UTF-8', 
                      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
                      'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.FILL_IN_THE_BLANK(URL, headers=request_header)
    soup = FILL_IN_THE_BLANK(response.text)
    imdb_rating = soup.find('FILL_IN_THE_BLANK', attrs={'FILL_IN_THE_BLANK' : 'FILL_IN_THE_BLANK'})
    return imdb_rating.text if imdb_rating else np.nan
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[249], line 3
#       1 import requests
#       2 import numpy as np
# ----> 3 from bs4 import FILL_IN_THE_BLANK
#       5 def scrapper(imdbId):
#       6     id = str(int(imdbId))
#
# ImportError: cannot import name 'FILL_IN_THE_BLANK' from 'bs4' (C:\Users\gowrabathina RAKESH\anaconda3\Lib\site-packages\bs4\__init__.py)

# %%
import requests
import numpy as np
from bs4 import BeautifulSoup

def scraper(imdbId):
    id_str = str(int(imdbId))
    n_zeroes = 7 - len(id_str)
    new_id = "0" * n_zeroes + id_str
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    
    request_headers = {
        'Content-Type': 'text/html; charset=UTF-8',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0',
        'Accept-Encoding': 'gzip, deflate, br'
    }
    
    response = requests.get(URL, headers=request_headers)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        
        imdb_rating_tag = soup.find('span', attrs={'itemprop': 'ratingValue'})
        
        return imdb_rating_tag.text.strip() if imdb_rating_tag else np.nan
    else:
        return np.nan

imdb_id = "15651"  #  IMDb ID for The Matrix (1999)
rating = scraper(imdb_id)
print(f"IMDb Rating: {rating}")
# Out:
# IMDb Rating: nan

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
 import requests
import numpy as np
from bs4 import BeautifulSoup
def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt%7Bnew_id%7D/"
    request_header = {'Content-Type': 'text/html; charset=UTF-8',
                      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0',
                      'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.get(URL, headers=request_header)
    soup = BeautifulSoup(response.text)
    imdb_rating = soup.find('span', attrs={'class' : 'sc-bde20123-1 cMEQkK'})
    return imdb_rating.text if imdb_rating else np.nan

# %%
df_merge_l
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy         5     4.0
# ...
