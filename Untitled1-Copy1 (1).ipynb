# %%
import pandas as pd

# %%
del_df=pd.read_csv(r"C:\Users\gowrabathina RAKESH\Downloads\deliveries.csv")

# %%
del_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
mat_df=pd.read_csv(r"C:\Users\gowrabathina RAKESH\Downloads\matches (3).csv")

# %%
mat_df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
mat_df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
del_df.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
#3. City which hosted most number of seasons according to the data is:
mat_df["city"].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
mat_df.groupby(["city","season"]).max().sum()
# Out:
# C:\Users\gowrabathina RAKESH\AppData\Local\Temp\ipykernel_25420\4131238108.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   mat_df.groupby(["city","season"]).max().sum()
# id                                                           218915
# date              2014-04-292010-03-282014-05-192015-04-242008-0...
# team1             Sunrisers HyderabadRajasthan RoyalsSunrisers H...
# team2             Rajasthan RoyalsRajasthan RoyalsRajasthan Roya...
# toss_winner       Rajasthan RoyalsRajasthan RoyalsRajasthan Roya...
# toss_decision     fieldfieldfieldfieldfieldfieldfieldfieldfieldf...
# result            tienormalnormaltienormalnormalnormalnormaltien...
# dl_applied                                                       19
# win_by_runs                                                    5535
# ...

# %%
#3. City which hosted most number of seasons according to the data is:
mat_df.concat(["season","city"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 #3. City which hosted most number of seasons according to the data is:
# ----> 2 mat_df.concat(["season","city"])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
mat_df.corr("city")
# Out:
# C:\Users\gowrabathina RAKESH\AppData\Local\Temp\ipykernel_25420\1643287031.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mat_df.corr("city")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 mat_df.corr("city")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10338, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10336             correl[j, i] = c
#   10337 else:
# > 10338     raise ValueError(
#   10339         "method must be either 'pearson', "
#   10340         "'spearman', 'kendall', or a callable, "
#   10341         f"'{method}' was supplied"
#   10342     )
#   10344 return self._constructor(correl, index=idx, columns=cols)
#
# ...

# %%
del_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
mat_df["season"].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
#Maximum wins by Mumbai Indians in 2011 are
for city in mat_df['city'].unique():
    print(f"{city}", end=" ")
    print(mat_df[mat_df['city']==city]['season'].sum())
# Out:
# Hyderabad 128927
# Pune 76563
# Rajkot 20165
# Indore 18145
# Bangalore 132861
# Mumbai 203344
# Kolkata 155078
# Delhi 149030
# Chandigarh 92582
# Kanpur 8066
# Jaipur 94622
# Chennai 114724
# Cape Town 14063
# Port Elizabeth 14063
# Durban 30135
# Centurion 24108
# East London 6027
# Johannesburg 16072
# Kimberley 6027
# Bloemfontein 4018
# Ahmedabad 24156
# Cuttack 14086
# Nagpur 6030
# Dharamsala 18103
# Kochi 10055
# Visakhapatnam 26203
# Raipur 12088
# Ranchi 14097
# Abu Dhabi 14098
# Sharjah 12084
# nan 0
# Mohali 20187
# Bengaluru 28259

# %% [raw]
# mat_df.groupby('winner')['season'].max()

# %%
mat_df.groupby('winner')['win_by_runs'].sum()
# Out:
# winner
# Chennai Super Kings            1778
# Deccan Chargers                 421
# Delhi Capitals                   92
# Delhi Daredevils                675
# Gujarat Lions                     1
# Kings XI Punjab                 925
# Kochi Tuskers Kerala             23
# Kolkata Knight Riders          1086
# Mumbai Indians                 1866
# Pune Warriors                   139
# Rajasthan Royals                895
# Rising Pune Supergiant          123
# Rising Pune Supergiants          53
# Royal Challengers Bangalore    1252
# Sunrisers Hyderabad             713
# Name: win_by_runs, dtype: int64

# %%
ipl_match[ipl_match['city']=='Hyderabad']['result_margin'].max()

# %%
mat_df[mat_df["year"]=="2011"]["win_by_runs"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
mat_df.groupby('winner')['win_by_runs'].sum()

# %%
mat_df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
del_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
mat_df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
mat_df[mat_df["winner"]=="Mumbai Indians"]["season"]=="2011".sum()
#Maximum wins by Mumbai Indians in 2011 are
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 mat_df[mat_df["winner"]=="Mumbai Indians"]["season"]=="2011".sum()
#
# AttributeError: 'str' object has no attribute 'sum'

# %%
mat_df.value_counts().plot.pie("autopct="%.1f%%)
# Out:
#   Cell In[48], line 1
#     mat_df.value_counts().plot.pie("autopct="%.1f%%)
#                                                ^
# SyntaxError: invalid decimal literal

# %%
mat_df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
del_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
del_df['bowler'].mode()
# Out:
# 0    Harbhajan Singh
# Name: bowler, dtype: object

# %%
del_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
mat_df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
20. which player has the highest hard-hitting ability?

# %%
import pandas as pd

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 mat_df
#
# NameError: name 'mat_df' is not defined

# %%
del_df=pd.read_csv(r"C:\Users\gowrabathina RAKESH\Downloads\deliveries.csv")

# %%
del_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
mat_df=pd.read_csv(r"C:\Users\gowrabathina RAKESH\Downloads\matches (3).csv")

# %%
mat_df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
matches = mat_df[(mat_df['season'] == 2011) & ((mat_df['team1'] == 'Mumbai Indians') | (mat_df['team2'] == 'Mumbai Indians'))]

# %%
matches.value_counts
# Out:
# <bound method DataFrame.value_counts of       id  season        city        date                        team1  \
# 237  238    2011       Delhi  2011-04-10             Delhi Daredevils
# 241  242    2011   Bangalore  2011-04-12  Royal Challengers Bangalore
# 246  247    2011      Mumbai  2011-04-15               Mumbai Indians
# 253  254    2011      Mumbai  2011-04-20                Pune Warriors
# 256  257    2011      Mumbai  2011-04-22               Mumbai Indians
# 259  260    2011   Hyderabad  2011-04-24               Mumbai Indians
# 266  267    2011      Jaipur  2011-04-29               Mumbai Indians
# 272  273    2011      Mumbai  2011-05-02               Mumbai Indians
# 276  277    2011      Mumbai  2011-05-04               Mumbai Indians
# 281  282    2011      Mumbai  2011-05-07               Mumbai Indians
# 286  287    2011  Chandigarh  2011-05-10              Kings XI Punjab
# 291  292    2011      Mumbai  2011-05-14              Deccan Chargers
# ...

# %%
matches = mat_df[(mat_df['season'] == 2011) & ((mat_df['team1'] == 'Mumbai Indians') | (mat_df['team2'] == 'Mumbai Indians'))]["winner"].value_counts().max()

# %%
matches
# Out:
# 10

# %%
del_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
mat_df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
mat_df["venue"].value_counts()
# Out:
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %%
del_df["dismissal_kind"].values
# Out:
# array([nan, nan, nan, ..., 'run out', nan, 'lbw'], dtype=object)

# %%
#12. Most number of wickets taken by a bowler is
del_df.groupby(del_df["bowler"],del_df["dismissal_kind"]=="wickets")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 #12. Most number of wickets taken by a bowler is
# ----> 2 del_df.groupby(del_df["bowler"],del_df["dismissal_kind"]=="wickets")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8400, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8398 if level is None and by is None:
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8400 axis = self._get_axis_number(axis)
#    8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    (...)
#    8412     dropna=dropna,
#    8413 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     550 @final
#     551 @classmethod
#     552 def _get_axis_number(cls, axis: Axis) -> int:
#     553     try:
# ...

# %%
wickets_by = del_df[del_df["dismissal_kind"] == "wickets"]("bowler").sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 wickets_by = del_df[del_df["dismissal_kind"] == "wickets"]("bowler").sum()
#
# TypeError: 'DataFrame' object is not callable

# %%
wickets_by_bowler
# Out:
# Empty DataFrame
# Columns: [match_id, inning, batting_team, bowling_team, over, ball, batsman, non_striker, is_super_over, wide_runs, bye_runs, legbye_runs, noball_runs, penalty_runs, batsman_runs, extra_runs, total_runs, player_dismissed, dismissal_kind, fielder]
# Index: []

# %%
wickets_by = del_df[del_df["dismissal_kind"] == "wickets"]["bowler"].sum()

# %%
wickets_by
# Out:
# 0

# %%
match_data = mat_df[(mat_df['season'] == 2017) &(((mat_df['team1'] == 'Sunrisers Hyderabad') & (mat_df['team2'] == 'Royal Challengers Bangalore')) |((mat_df['team1'] == 'Royal Challengers Bangalore') & (mat_df['team2'] == 'Sunrisers Hyderabad')))]

# %%
match_data
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2 umpire3
# 0  NJ Llong     NaN

# %%
del_df[(del_df['batsman']=='V Kohli') & (del_df['bowler']=='JJ Bumrah')]['total_runs'].sum()
# Out:
# 114
